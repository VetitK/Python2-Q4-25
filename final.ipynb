# %%
class CryptoPortfolio:
    def __init__(self, path_to_portfolio: str):
        self.api_link = "https://api.binance.com/api/v3/ticker/price?symbol="
    
    def get_all_coins_symbol(self):
        return
