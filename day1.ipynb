# %% [markdown]
# $a^2 + b^2 = c^2$

# %% [markdown]
# $x=\frac{-b \pm \sqrt{b^2-4ac}}{2a}$

# %% [markdown]
# # Day 1

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ## Content

# %% [markdown]
# ```python
# import
# Error handling
# Functions
# Class - OOP (Object-oriented programming) / การเขียนโปรแกรมเชิงวัตถุ
# ```

# %% [markdown]
# ## ทวน

# %%
print(2+2)
print("Hello")
print(3**2)

if 2 > 3:
    print("A")
elif 4 > 2:
    print("B")
else:
    print("C")
    
for i in range(6):
    print(i+1)
    
x = 0
while x < 10:
    print("Hi")
    x += 1
# Out:
# 4
# Hello
# 9
# B
# 1
# 2
# 3
# 4
# 5
# 6
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi

# %%
sentence = "I love Bangkok!"
print(len(sentence))
print("l" in sentence)

sentence.upper()
# Out:
# 15
# True
# 'I LOVE BANGKOK!'

# %%
sentence = "I love Bangkok!"
for character in sentence:
    print(character)
# Out:
# I
#
# l
# o
# v
# e
#
# B
# a
# n
# g
# k
# o
# k
# !

# %%
sentence = "I love Bangkok!"
sentence[2]
sentence[-1]
sentence[-2]

sentence[11:14] # 11,12,13
sentence[1:5:2] # 1,3
sentence[::-1] # reversed
# Out:
# '!kokgnaB evol I'

# %%
l = [1, 2, 3]
# l.append(4)
# l.insert(3, 4)
# l.extend([4])
# l += [4]
# l = l + [4]
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l = [1, 2, 3, 4]
# l.remove(4)
l.pop(0)
l
# Out:
# [2, 3, 4]

# %% [markdown]
# # Import

# %% [markdown]
# built-in library (มีมาให้)
#
# external library (ต้องไปโหลดมา)

# %% [markdown]
# math
#
# time
#
# random

# %%
import math
import math as ikq # alias

# %%
print(ikq.pi) 
print(ikq.gcd(4, 6, 10))
print(ikq.lcm(4, 6, 10))
# Out:
# 3.141592653589793
# 2
# 60

# %%
from math import gcd, lcm, exp
from math import * # import ทุกอย่าง / ไม่แนะนำ
gcd(2, 6)
exp(5)
# Out:
# 148.4131591025766

# %% [markdown]
# $\sqrt{5}$

# %% [markdown]
# $\sqrt{5}=5^{\frac{1}{2}}$
#
# $\sqrt[a]{x^n} = x^{\frac{n}{a}}$

# %%
print(5 ** (1/2))
print(math.sqrt(5))
# Out:
# 2.23606797749979
# 2.23606797749979

# %% [markdown]
# time

# %%
import time

# %%
seconds = 10
for i in range(5):
    print(i)
    time.sleep(seconds)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
t_start = time.time()
99999 ** 999999
t_end = time.time()
print(t_end - t_start)
# Out:
# 3.3266549110412598

# %% [markdown]
# random

# %%
import random

# %%
# 0-1
random.random()
random.randint(1,10)
# Out:
# 5

# %%
random.random() # 0-1

random.random() + 1 # 1-2

round(random.random() + 1, 3)

# 3 - 6
# 3.45435, 5.4392493, 4.48328432,
random.random() + random.randint(3,5)
(random.random() * 3) + 3
# Out:
# 5.226701118688607

# %%
random.randint(1, 10)
random.choice(["A", "B", "C", "D"])
random.choices(["A", "B", "C", "D"], k=3)
# Out:
# ['D', 'A', 'A']

# %%
import random
random.seed(0)

# %%
print(random.random())
# Out:
# 0.420571580830845

# %% [markdown]
# os - Operating System

# %%
import os
# directory

os.listdir('img')
# Out:
# ['2.jpg', '3.jpg', '1.jpg']

# %%
os.remove('img/2.jpg')
